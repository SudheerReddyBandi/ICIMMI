# %%
# Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import plotly.graph_objects as go

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing the dataset
dataset = pd.read_csv('/content/drive/MyDrive/2019_spatial_master_data_conf.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31804 entries, 0 to 31803
# Data columns (total 34 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   centroid_x                                                     31804 non-null  float64
#  1   centroid_y                                                     31804 non-null  float64
#  2   c_percent WFH                                                  31804 non-null  float64
#  3   c_percent part-time                                            31804 non-null  float64
#  4   c_percent 15 hours or less worked                              31804 non-null  float64
#  5   c_percent 49 or more hours worked                              31804 non-null  float64
#  6   c_percent full-time                                            31804 non-null  float64
# ...

# %%
df1=dataset

# %%
df2=df1.head()

# %%
df2
# Out:
#     centroid_x   centroid_y  c_percent WFH  c_percent part-time  \
# 0  532151.1942  181615.2014       0.739583             0.190531
# 1  532443.6860  181645.7249       0.769056             0.149714
# 2  532207.0148  182030.1296       0.618619             0.210000
# 3  533618.3485  181157.3543       0.407631             0.267068
# 4  544934.3697  184297.5465       0.216704             0.363431
#
#    c_percent 15 hours or less worked  c_percent 49 or more hours worked  \
# 0                           0.098152                           0.307159
# 1                           0.060571                           0.358857
# 2                           0.078000                           0.245000
# 3                           0.114458                           0.124498
# 4                           0.133183                           0.091422
#
#    c_percent full-time  c_percent 1. Managers directors and senior officials  \
# ...

# %%
dataset.describe()
# Out:
#           centroid_x     centroid_y  c_percent WFH  c_percent part-time  \
# count   31804.000000   31804.000000   31804.000000         31804.000000
# mean   454562.247061  276758.664481       0.303732             0.305333
# std     83767.645542  127298.143884       0.128536             0.052068
# min    136699.430800   16220.991440       0.031136             0.077821
# 25%    393575.691150  175235.882575       0.205702             0.273892
# 50%    448879.665550  261211.190500       0.286544             0.300960
# 75%    524271.312300  389700.000900       0.385879             0.332372
# max    655228.480000  654532.835500       0.769056             0.766102
#
#        c_percent 15 hours or less worked  c_percent 49 or more hours worked  \
# count                       31804.000000                       31804.000000
# mean                            0.105110                           0.108403
# std                             0.029380                           0.040204
# ...

# %%
df1 = dataset.dropna()

# %%
df1.describe()
# Out:
#           centroid_x     centroid_y  c_percent WFH  c_percent part-time  \
# count   31793.000000   31793.000000   31793.000000         31793.000000
# mean   454575.926966  276764.276020       0.303715             0.305317
# std     83762.673800  127298.695318       0.128529             0.052069
# min    136699.430800   16220.991440       0.031136             0.077821
# 25%    393618.870500  175245.833800       0.205703             0.273878
# 50%    448896.644400  261222.751200       0.286533             0.300940
# 75%    524263.422600  389690.705100       0.385820             0.332362
# max    655228.480000  654532.835500       0.769056             0.766102
#
#        c_percent 15 hours or less worked  c_percent 49 or more hours worked  \
# count                       31793.000000                       31793.000000
# mean                            0.105104                           0.108400
# std                             0.029381                           0.040208
# ...

# %%
corrmat = df1.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(30,30))
#Plotting heat map
g=sns.heatmap(df1[top_corr_features].corr(),annot=True,linewidths=.5)
b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.title('Correlation Matrix',fontdict = {'fontsize' : 20})
plt.savefig('/content/drive/MyDrive/ICIMMI/corr_matrix.png', format='png', dpi=600)
plt.show()

# %%
import pandas as pd
from sklearn import preprocessing

x = df1.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_normal = pd.DataFrame(x_scaled)

# %%
print(df_normal.head(1))
# Out:
#          0         1        2         3         4        5         6   \
# 0  0.762641  0.259112  0.96006  0.163756  0.127741  0.61199  0.836244
#
#          7         8         9   ...        24        25        26        27  \
# 0  0.522233  0.741262  0.323381  ...  0.297485  0.199007  0.036023  0.024281
#
#          28        29       30        31        32        33
# 0  0.082577  0.019293  0.00075  0.004211  0.003481  0.003221
#
# [1 rows x 34 columns]

# %%
df2_normal=df_normal

# %%
df2_normal.describe()
# Out:
#                  0             1             2             3             4   \
# count  31793.000000  31793.000000  31793.000000  31793.000000  31793.000000
# mean       0.613035      0.408176      0.369389      0.330529      0.140184
# std        0.161539      0.199430      0.174177      0.075650      0.052594
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.495477      0.249133      0.236566      0.284850      0.105957
# 50%        0.602082      0.383828      0.346104      0.324169      0.133201
# 75%        0.747430      0.585090      0.480655      0.369821      0.165671
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  5             6             7             8             9   \
# count  31793.000000  31793.000000  31793.000000  31793.000000  31793.000000
# mean       0.203429      0.669471      0.287497      0.288330      0.181481
# ...

# %%
df2_normal.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.762641  0.259112  0.960060  0.163756  0.127741  0.611990  0.836244
# 1  0.763206  0.259160  1.000000  0.104453  0.060467  0.718257  0.895547
# 2  0.762749  0.259762  0.796134  0.192042  0.091666  0.484218  0.807958
# 3  0.765471  0.258395  0.510211  0.274957  0.156929  0.236520  0.725043
# 4  0.787294  0.263314  0.251475  0.414962  0.190449  0.168531  0.585038
#
#          7         8         9   ...        24        25        26        27  \
# 0  0.522233  0.741262  0.323381  ...  0.297485  0.199007  0.036023  0.024281
# 1  0.586247  0.755863  0.325208  ...  0.188203  0.179401  0.025905  0.015766
# 2  0.443110  0.613868  0.328646  ...  0.406890  0.116676  0.040845  0.021636
# 3  0.235036  0.398447  0.165641  ...  0.166549  0.133184  0.022949  0.012981
# 4  0.184185  0.199383  0.152301  ...  0.751471  0.084396  0.097937  0.047759
#
#          28        29        30        31        32        33
# ...

# %%
corrmat = df_normal.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(30,30))
#Plotting heat map
g=sns.heatmap(df_normal[top_corr_features].corr(),annot=True,linewidths=.5, cmap= 'Purples')
b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.title('Correlation Matrix',fontdict = {'fontsize' : 20})
plt.savefig('/content/drive/MyDrive/ICIMMI/normalized_corr_matrix.png', format='png', dpi=600)
plt.show()

# %%
# Splitting the dataset into features and outcome variable(Overall)
y = df_normal.iloc[:,33].values
# Picking up the top ten most useful features based on the above heatmap
x = df1[['centroid_x','centroid_y','c_percent WFH','c_percent 2. Professional occupations','c_percent 5. Skilled trades occupations','c_percent 6. Caring leisure and other service occupations','c_percent very good health','c_percent good health','c_percent fair health','c_percent bad health','e_NO2','e_ozone','o_opioids_quantity_per_capita','o_hypertension_quantity_per_capita','o_depression_quantity_per_capita'
            ]].values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)

# Get the column names for the selected features
selected_columns = ['centroid_x','centroid_y','c_percent WFH','c_percent 2. Professional occupations','c_percent 5. Skilled trades occupations','c_percent 6. Caring leisure and other service occupations','c_percent very good health','c_percent good health','c_percent fair health','c_percent bad health','e_NO2','e_ozone','o_opioids_quantity_per_capita','o_hypertension_quantity_per_capita','o_depression_quantity_per_capita']

# Assign the correct column names to df_normal_x
df_normal_x = pd.DataFrame(x_scaled, columns=selected_columns)  # This is the crucial change

y_scaled = min_max_scaler.fit_transform(y.reshape(-1, 1))

# Assign column names from df1 to df_normal_y
df_normal_y = pd.DataFrame(y_scaled)  # This is the crucial change

# %%
print(x.shape)
# Out:
# (31793, 15)

# %%
print(x)
# Out:
# [[5.32151194e+05 1.81615201e+05 7.39583333e-01 ... 1.32050734e-01
#   1.05729037e+00 3.21219512e-01]
#  [5.32443686e+05 1.81645725e+05 7.69055745e-01 ... 2.83110738e-01
#   1.39177777e+00 4.92456942e-01]
#  [5.32207015e+05 1.82030130e+05 6.18618619e-01 ... 5.88814605e-01
#   2.30408661e+00 9.31698027e-01]
#  ...
#  [3.34965282e+05 3.88602954e+05 2.33830846e-01 ... 6.39210985e+00
#   1.80770827e+01 8.98942320e+00]
#  [3.35637289e+05 3.87579285e+05 2.45370370e-01 ... 6.90209958e+00
#   1.88148753e+01 9.32280638e+00]
#  [3.35906707e+05 3.89400268e+05 3.37268128e-01 ... 1.85339600e+01
#   5.83367226e+01 2.95391702e+01]]

# %%
print(y.shape)
# Out:
# (31793,)

# %%
print(y)
# Out:
# [0.00322095 0.00542235 0.01013609 ... 0.10669281 0.1099258  0.34889105]

# %%
print(df_normal_x.head)
# Out:
# <bound method NDFrame.head of        centroid_x  centroid_y  c_percent WFH  \
# 0        0.762641    0.259112       0.960060
# 1        0.763206    0.259160       1.000000
# 2        0.762749    0.259762       0.796134
# 3        0.765471    0.258395       0.510211
# 4        0.787294    0.263314       0.251475
# ...           ...         ...            ...
# 31788    0.381546    0.586869       0.243956
# 31789    0.386177    0.586071       0.227389
# 31790    0.382362    0.583386       0.274685
# 31791    0.383658    0.581782       0.290322
# 31792    0.384178    0.584635       0.414859
#
#        c_percent 2. Professional occupations  \
# 0                                   0.741262
# 1                                   0.755863
# 2                                   0.613868
# 3                                   0.398447
# 4                                   0.199383
# ...                                      ...
# 31788                               0.243306
# ...

# %%
print(df_normal_y)
# Out:
#               0
# 0      0.003221
# 1      0.005422
# 2      0.010136
# 3      0.013243
# 4      0.086277
# ...         ...
# 31788  0.250858
# 31789  0.388886
# 31790  0.106693
# 31791  0.109926
# 31792  0.348891
#
# [31793 rows x 1 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Convert x back to a Pandas DataFrame
x1 = pd.DataFrame(x, columns=['centroid_x','centroid_y','c_percent WFH','c_percent 2. Professional occupations','c_percent 5. Skilled trades occupations','c_percent 6. Caring leisure and other service occupations','c_percent very good health','c_percent good health','c_percent fair health','c_percent bad health','e_NO2','e_ozone','o_opioids_quantity_per_capita','o_hypertension_quantity_per_capita','o_depression_quantity_per_capita'])
y1 = pd.DataFrame(y, columns=['Overall'])

z = pd.concat([x1, y1], axis=1)
corrmat = z.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(25,25))
#Plotting heat map
g=sns.heatmap(z.corr(),annot=True,linewidths=.5, cmap='Blues') # x is now a DataFrame and has .corr()
b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.title('Correlation Matrix',fontdict = {'fontsize' : 20})
plt.savefig('/content/drive/MyDrive/ICIMMI/corr_matrix_reduced_features.png', format='png', dpi=600)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Convert x back to a Pandas DataFrame
x1 = pd.DataFrame(df_normal_x, columns=['centroid_x','centroid_y','c_percent WFH','c_percent 2. Professional occupations','c_percent 5. Skilled trades occupations','c_percent 6. Caring leisure and other service occupations','c_percent very good health','c_percent good health','c_percent fair health','c_percent bad health','e_NO2','e_ozone','o_opioids_quantity_per_capita','o_hypertension_quantity_per_capita','o_depression_quantity_per_capita'])
y1 = pd.DataFrame(y, columns=['Overall'])

z = pd.concat([x1, y1], axis=1)
corrmat = z.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(25,25))
#Plotting heat map
g=sns.heatmap(z.corr(),annot=True,linewidths=.5, cmap='Blues') # x is now a DataFrame and has .corr()
b, t = plt.ylim()
b += 0.5
t -= 0.5
plt.ylim(b, t)
plt.title('Correlation Matrix',fontdict = {'fontsize' : 20})
plt.savefig('/content/drive/MyDrive/ICIMMI/corr_matrix_reduced_features.png', format='png', dpi=600)
plt.show()

# %%
# Splitting the dataset into training and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df_normal_x,y,test_size=0.2,random_state=0)

# %%
## Training the multiple linear regression on the training set
from sklearn.linear_model import LinearRegression
regressor_MultiLinear = LinearRegression()
MLR=regressor_MultiLinear.fit(x_train,y_train)

# %%
## Predicting test results
y_pred = regressor_MultiLinear.predict(x_test)

# %%
print(y_pred)
# Out:
# [0.3959969  0.56441198 0.19401188 ... 0.54969404 0.54980665 0.41146183]

# %%
# Calculating r2 score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
r2_MultiLinear = r2_score(y_test,y_pred)
print(r2_MultiLinear)
# Out:
# 0.9846770222896836

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))

# %%
from statistics import mean
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.0005528058425576823
# 0.0005528058425576823
# 0.017104446341812317

# %%
import statsmodels.api as sm

# Perform multiple linear regression using ordinary least-squares
model = sm.OLS(y_train, x_train)
# Fit the model
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          5.368e+05
# Date:                Fri, 25 Oct 2024   Prob (F-statistic):                        0.00
# Time:                        06:56:54   Log-Likelihood:                          59845.
# No. Observations:               25434   AIC:                                 -1.197e+05
# Df Residuals:                   25419   BIC:                                 -1.195e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import statsmodels.api as sm

# Perform multiple linear regression using ordinary least-squares
model = sm.OLS(y_test, x_test)
# Fit the model
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.304e+05
# Date:                Fri, 25 Oct 2024   Prob (F-statistic):                        0.00
# Time:                        06:57:38   Log-Likelihood:                          14829.
# No. Observations:                6359   AIC:                                 -2.963e+04
# Df Residuals:                    6344   BIC:                                 -2.953e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
## Finding out the optimal degree of polynomial regression
from sklearn.preprocessing import PolynomialFeatures
sns.set_style('darkgrid')
scores_list = []
pRange = range(2,6)
for i in pRange :
    poly_reg = PolynomialFeatures(degree=i)
    x_poly = poly_reg.fit_transform(x_train)
    poly_regressor = LinearRegression()
    poly_regressor.fit(x_poly,y_train)
    y_pred = poly_regressor.predict(poly_reg.fit_transform(x_test))
    scores_list.append(r2_score(y_test,y_pred))
plt.plot(pRange,scores_list,linewidth=2)
plt.xlabel('Degree of polynomial')
plt.ylabel('r2 score with varying degrees')
plt.savefig('/content/drive/MyDrive/ICIMMI/find_poly_degree.png', format='png', dpi=600)
plt.show()

# %%
#Training the polynomial regression on the training model
poly_reg = PolynomialFeatures(degree=2)
x_poly = poly_reg.fit_transform(x_train)
poly_regressor = LinearRegression()
poly_regressor.fit(x_poly,y_train)
y_pred = poly_regressor.predict(poly_reg.fit_transform(x_test))
r2_poly = r2_score(y_test,y_pred)
print(r2_poly)
# Out:
# 0.9846770222896836

# %%
#Training the polynomial regression on the training model
poly_reg = PolynomialFeatures(degree=3)
x_poly = poly_reg.fit_transform(x_train)
poly_regressor = LinearRegression()
poly_regressor.fit(x_poly,y_train)
y_pred = poly_regressor.predict(poly_reg.fit_transform(x_test))
r2_poly = r2_score(y_test,y_pred)
print(r2_poly)
# Out:
# 0.9875387929381926

# %%
#Training the polynomial regression on the training model
poly_reg = PolynomialFeatures(degree=4)
x_poly = poly_reg.fit_transform(x_train)
poly_regressor = LinearRegression()
poly_regressor.fit(x_poly,y_train)
y_pred = poly_regressor.predict(poly_reg.fit_transform(x_test))
r2_poly = r2_score(y_test,y_pred)
print(r2_poly)
# Out:
# 0.9868957284375329

# %%
#Training the polynomial regression on the training model
poly_reg = PolynomialFeatures(degree=5)
x_poly = poly_reg.fit_transform(x_train)
poly_regressor = LinearRegression()
poly_regressor.fit(x_poly,y_train)
y_pred = poly_regressor.predict(poly_reg.fit_transform(x_test))
r2_poly = r2_score(y_test,y_pred)
print(r2_poly)
# Out:
# 0.7282352545213884

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.00047051871593410867
# 0.0004705187159341087
# 0.015785913504367474

# %%
## Finding the optimal number of neighbors for KNN regression
from sklearn.neighbors import KNeighborsRegressor
knnRange = range(1,21,1)
scores_list = []
for i in knnRange:
    regressor_knn = KNeighborsRegressor(n_neighbors=i)
    regressor_knn.fit(x_train,y_train)
    y_pred = regressor_knn.predict(x_test)
    scores_list.append(r2_score(y_test,y_pred))
plt.plot(knnRange,scores_list,linewidth=2,color='green')
plt.xticks(knnRange)
plt.xlabel('No. of neighbors')
plt.ylabel('r2 score of KNN')
plt.savefig('/content/drive/MyDrive/ICIMMI/k_identification_features.png', format='png', dpi=600)
plt.show()
#plt.savefig('/content/drive/MyDrive/ICIMMI/corr_matrix_reduced_features.png', format='png', dpi=600)

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=2)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.971689288027821

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=3)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.9745778746623917

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=4)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.9760533797651089

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=5)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.9766087387604384

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=6)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.9767831230348902

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=7)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.9767030835790336

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=8)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.976617590189857

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=9)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.9767130652237517

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.000715065887068726
# 0.000715065887068726
# 0.020496596063022527

# %%
# Training the KNN model on the training set
regressor_knn = KNeighborsRegressor(n_neighbors=6)
regressor_knn.fit(x_train,y_train)
y_pred = regressor_knn.predict(x_test)
r2_knn = r2_score(y_test,y_pred)
print(r2_knn)
# Out:
# 0.9767831230348902

# %%
from statistics import mean
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.000715065887068726
# 0.000715065887068726
# 0.020496596063022527

# %%
# Training the Decision Tree regression on the training model
from sklearn.tree import DecisionTreeRegressor
regressor_Tree = DecisionTreeRegressor(random_state=0)
regressor_Tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# Predicting test results
y_pred = regressor_Tree.predict(x_test)

# %%
# Calculating r2 score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
r2_tree = r2_score(y_test,y_pred)
print(r2_tree)
# Out:
# 0.9857127644812315

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.0004387144481723817
# 0.00043871444817238174
# 0.013236337330158703

# %%
# Finding out the optimal number of trees for Random Forest Regression
from sklearn.ensemble import RandomForestRegressor
forestRange=range(50,500,50)
scores_list=[]
for i in forestRange:
    regressor_Forest = RandomForestRegressor(n_estimators=i,random_state=0)
    regressor_Forest.fit(x_train,y_train)
    y_pred = regressor_Forest.predict(x_test)
    scores_list.append(r2_score(y_test,y_pred))
plt.plot(forestRange,scores_list,linewidth=2,color='maroon')
plt.xticks(forestRange)
plt.xlabel('No. of trees')
plt.ylabel('r2 score of Random Forest Reg.')
plt.savefig('/content/drive/MyDrive/ICIMMI/RF_features.png', format='png', dpi=600)
plt.show()

# %%
# Training the Random Forest regression on the training model
regressor_Forest = RandomForestRegressor(n_estimators=150,random_state=0)
regressor_Forest.fit(x_train,y_train)
y_pred = regressor_Forest.predict(x_test)
r2_forest = r2_score(y_test,y_pred)
print(r2_forest)
# Out:
# 0.9930721446389468

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.00021273186388996617
# 0.0002127318638899662
# 0.009756750698536985

# %%
# Training the Random Forest regression on the training model
regressor_Forest = RandomForestRegressor(n_estimators=200,random_state=0)
regressor_Forest.fit(x_train,y_train)
y_pred = regressor_Forest.predict(x_test)
r2_forest = r2_score(y_test,y_pred)
print(r2_forest)
# Out:
# 0.9930799094974017

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.0002124934303884158
# 0.00021249343038841578
# 0.009749616802317954

# %%
# Training the Random Forest regression on the training model
regressor_Forest = RandomForestRegressor(n_estimators=250,random_state=0)
regressor_Forest.fit(x_train,y_train)
y_pred = regressor_Forest.predict(x_test)
r2_forest = r2_score(y_test,y_pred)
print(r2_forest)
# Out:
# 0.9930824926484111

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.00021241411023805373
# 0.00021241411023805376
# 0.009743117684525125

# %%
# Training the Random Forest regression on the training model
regressor_Forest = RandomForestRegressor(n_estimators=300,random_state=0)
regressor_Forest.fit(x_train,y_train)
y_pred = regressor_Forest.predict(x_test)
r2_forest = r2_score(y_test,y_pred)
print(r2_forest)
# Out:
# 0.9930796253018975

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = abs((y_test - y_pred))
print(mean(error))
print(Mean_Squared_Error)
print(mean(Absolute_error))
# Out:
# 0.0002125021571063059
# 0.00021250215710630588
# 0.009740687403093537

# %%
## Feature Scaling for SVR
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(np.reshape(y_train,(len(y_train),1)))
y_test = sc_y.transform(np.reshape(y_test,(len(y_test),1)))

# %%
## Training the Linear SVR model on the training set
from sklearn.svm import SVR
regressor_SVR = SVR(kernel='linear')
regressor_SVR.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
## Predicting test results
y_pred = regressor_SVR.predict(x_test)

# %%
## Calculating r2 score
r2_linearSVR = r2_score(y_test,y_pred)
print(r2_linearSVR)
# Out:
# 0.981942891235891

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = mean_absolute_error(y_test, y_pred)

print(Mean_Squared_Error)
print((Absolute_error))
print(np.mean(error))
# Out:
# 0.017940536990910652
# 0.097326694795677
# 1.965816160072639

# %%
## Training the Non-linear SVR model on the training set
from sklearn.svm import SVR
regressor_NonLinearSVR = SVR(kernel='rbf')
regressor_NonLinearSVR.fit(x_train,y_train)
# Out:
# SVR()

# %%
## Predicting test results
y_pred = regressor_NonLinearSVR.predict(x_test)

# %%
## Calculating r2 score
r2_NonlinearSVR = r2_score(y_test,y_pred)
print(r2_NonlinearSVR)
# Out:
# 0.9875345793225011

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = mean_absolute_error(y_test, y_pred)

print(Mean_Squared_Error)
print((Absolute_error))
# Out:
# 0.012384947318722368
# 0.08148062072417185

# %%
## Training the Non-linear SVR model on the training set
from sklearn.svm import SVR
regressor_NonLinearSVR = SVR(kernel='poly')
regressor_NonLinearSVR.fit(x_train,y_train)

## Predicting test results
y_pred = regressor_NonLinearSVR.predict(x_test)

## Calculating r2 score
r2_NonlinearSVR = r2_score(y_test,y_pred)
print(r2_NonlinearSVR)
# Out:
# 0.912618142916229

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = mean_absolute_error(y_test, y_pred)

print(Mean_Squared_Error)
print((Absolute_error))
# Out:
# 0.08681774362802931
# 0.2108993168398161

# %%
## Applying the XGBoost Regression model on the training set
from xgboost import XGBRegressor
regressor_xgb = XGBRegressor()
regressor_xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
## Predicting test results
y_pred = regressor_xgb.predict(x_test)

# %%
## Calculating r2 score
r2_xgb = r2_score(y_test,y_pred)
print(r2_xgb)
# Out:
# 0.9949615895383918

# %%
from statistics import mean
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
error = (y_test - y_pred)**2
# calculate errors
Mean_Squared_Error = mean_squared_error(y_test, y_pred)
# calculate error
Absolute_error = mean_absolute_error(y_test, y_pred)

print(Mean_Squared_Error)
print((Absolute_error))
# Out:
# 0.005005883856752291
# 0.050423829072362876

# %%
## Comparing the r2 scores of different models
labelList = ['Multiple Linear Reg.','Polynomial Reg.','K-NearestNeighbors','Decision Tree','Random Forest',
             'Linear SVR','Non-Linear SVR','XGBoost Reg.']
mylist = [r2_MultiLinear,r2_poly,r2_knn,r2_tree,r2_forest,r2_linearSVR,r2_NonlinearSVR,r2_xgb]
for i in range(0,len(mylist)):
    mylist[i]=np.round(mylist[i]*100,decimals=2)
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-c7f700f0ac17> in <cell line: 4>()
#       2 labelList = ['Multiple Linear Reg.','Polynomial Reg.','K-NearestNeighbors','Decision Tree','Random Forest',
#       3              'Linear SVR','Non-Linear SVR','XGBoost Reg.']
# ----> 4 mylist = [r2_MultiLinear,r2_poly,r2_knn,r2_tree,r2_forest,r2_linearSVR,r2_NonlinearSVR,r2_xgb]
#       5 for i in range(0,len(mylist)):
#       6     mylist[i]=np.round(mylist[i]*100,decimals=2)
#
# NameError: name 'r2_MultiLinear' is not defined

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x=labelList,y=mylist)
plt.yticks(np.arange(0, 101, step=10))
plt.title('r2 score comparison among different regression models',fontweight='bold')
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.annotate('{:.2f}%'.format(height), (x +0.25, y + height + 0.25))
plt.show()

# %%
## Comparing the r2 scores of different models
labelList = ['Multiple Linear Reg.','Polynomial Reg.','K-NearestNeighbors','Decision Tree','Random Forest','Non-Linear SVR']
mylist = [r2_MultiLinear,r2_poly,r2_knn,r2_tree,r2_forest,r2_NonlinearSVR]
for i in range(0,len(mylist)):
    mylist[i]=np.round(mylist[i]*100,decimals=2)
print(mylist)
# Out:
# [98.2, 98.61, 93.7, 98.52, 99.31, 98.75]

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x=labelList,y=mylist)
plt.yticks(np.arange(0, 101, step=10))
plt.title('r2 score comparison among different regression models',fontweight='bold')
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.annotate('{:.2f}%'.format(height), (x +0.25, y + height + 0.25))
plt.show()
